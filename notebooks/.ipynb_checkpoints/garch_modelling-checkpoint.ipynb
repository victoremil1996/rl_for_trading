# %%
"""
Magic commands
"""
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

"""
Python standard packages
"""
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

"""
packages for dataload and simulation
"""
import ffn # data access
from arch import arch_model  # simulation
from arch.univariate import SkewStudent, GARCH, EGARCH, ARX
"""
Own packages
"""
sys.path.insert(0, "C:\\code\\speciale\\") # vsl path
sys.path.insert(0, "C:\\user\\noob\\")

import codelib

"""
ignore warnings
"""
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load and manipulate data

# %%
prices = ffn.get('aapl,msft, fing-b.st, spy', start = '2018-01-01')
returns = prices.to_returns().dropna()
log_returns = prices.to_log_returns().dropna()
cum_returns = prices.rebase()

# %%
cum_returns.plot(figsize = (12, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Modelling and simulation

# %%
np.random.seed(0)
print(np.random.normal(size = 10))
# Out:
# [ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788
#   0.95008842 -0.15135721 -0.10321885  0.4105985 ]

# %%
# FIT MODEL
rs = np.random.RandomState([0])

n_sims = 30
stock = 'aapl'
n_time_points = 1000

# Model specification
dist = SkewStudent(random_state = rs)
vol = EGARCH()
lag = [1, 2, 3, 4, 5]

# Model calibration
am = ARX(returns[stock] * 100, lags = lag, volatility = vol, distribution = dist)
am_fit = am.fit()
#am = arch_model(returns[stock] * 100, mean = "AR", vol = "garch", dist= skew_t) # fit garch model


# Model Simulation
fig, ax = plt.subplots(figsize = (12, 6))
ax.set(xlabel = "time", ylabel = "return")


for _ in range(n_sims):
    simulation = am.simulate(params = am_fit.params, nobs = n_time_points) / 100
    sim_prices = simulation.data.to_price_index()
    
    ax.plot(sim_prices, alpha = 30)
# Out:
# Iteration:      1,   Func. Count:     13,   Neg. LLF: 45275.60456807088
# Iteration:      2,   Func. Count:     29,   Neg. LLF: 33517.81103617677
# Iteration:      3,   Func. Count:     45,   Neg. LLF: 55833.63568090619
# Iteration:      4,   Func. Count:     61,   Neg. LLF: 10777.864661080861
# Iteration:      5,   Func. Count:     76,   Neg. LLF: 140212.7654327307
# Iteration:      6,   Func. Count:     90,   Neg. LLF: 10448.200336238442
# Iteration:      7,   Func. Count:    104,   Neg. LLF: 32807.994174177846
# Iteration:      8,   Func. Count:    119,   Neg. LLF: 70269.36213159737
# Iteration:      9,   Func. Count:    134,   Neg. LLF: 35558.271101540624
# Iteration:     10,   Func. Count:    148,   Neg. LLF: 4272.057502672805
# Iteration:     11,   Func. Count:    163,   Neg. LLF: 3034.3365885484595
# Iteration:     12,   Func. Count:    176,   Neg. LLF: 2068.8184812263307
# Iteration:     13,   Func. Count:    189,   Neg. LLF: 2068.2913610118776
# Iteration:     14,   Func. Count:    201,   Neg. LLF: 2068.279483142617
# Iteration:     15,   Func. Count:    213,   Neg. LLF: 2068.2714835812544
# Iteration:     16,   Func. Count:    225,   Neg. LLF: 2068.270015707927
# Iteration:     17,   Func. Count:    237,   Neg. LLF: 2068.2697953108946
# Iteration:     18,   Func. Count:    249,   Neg. LLF: 2068.270198135138
# Iteration:     19,   Func. Count:    263,   Neg. LLF: 2068.2695989997796
# Iteration:     20,   Func. Count:    275,   Neg. LLF: 2068.2695515789437
# Iteration:     21,   Func. Count:    287,   Neg. LLF: 2068.2695493526517
# Iteration:     22,   Func. Count:    299,   Neg. LLF: 2068.269547976115
# Iteration:     23,   Func. Count:    311,   Neg. LLF: 2068.2695450527026
# Iteration:     24,   Func. Count:    323,   Neg. LLF: 2068.2695614576396
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2068.2695448464196
#             Iterations: 24
#             Function evaluations: 324
#             Gradient evaluations: 24

# %% [markdown]
# ## create features

# %%
df_test = pd.DataFrame({"price":sim_prices})

# %%
df_test.create_features()
# Out:
#           price        ma_5       ma_50
# 0     99.117942         NaN         NaN
# 1    102.326047         NaN         NaN
# 2    101.753409         NaN         NaN
# 3    103.625574         NaN         NaN
# 4    102.735671  101.911729         NaN
# ..          ...         ...         ...
# 995  874.045157  870.949211  820.011667
# 996  879.322318  874.406006  822.568991
# 997  893.371775  879.107518  825.123053
# 998  905.748575  884.743889  827.243525
# 999  927.850759  896.067717  829.754913
#
# [1000 rows x 3 columns]
